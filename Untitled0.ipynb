# %% [markdown]
# <a href="https://colab.research.google.com/github/rui-2007noyabr-cmyk/-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
foods = {
    "おにぎり": {
       "gi":80,
       "peak":30,
       "down":100,
    },
    "バナナ": {
      "gi":55,
      "peak":45,
      "down":120,
    },
    "オートミール": {
      "gi":50,
      "peak":60,

      "down":150,
    }
}

food_name = input("食材を入力:")
print(f"入力された食材: {food_name}")

if food_name in foods:
    if foods[food_name]["gi"] > 70:
      print("シュガースパイク")
    else:
      print("血糖値安定")
else:
    print(f"{food_name} のデータはありません。")
# Out:
# 食材を入力:ごりら
# 入力された食材: ごりら
# ごりら のデータはありません。
